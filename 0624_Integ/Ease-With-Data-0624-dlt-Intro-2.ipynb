# %%
# Create a  View for Customers -- July 4, 2025 #29vid
@dlt.view(
  comment = "Customer bronze view"
)
def customer_bronze_vw2(): # Change
  df = spark.readStream.table("0624_integ.0624_schema.customer_raw_bronze")
  return df

# %%
@dlt.table(
  table_properties = {"quality": "bronze"},
  comment = "Order bronze table"
)
def orders_bronze():
  df = spark.readStream.table("0624_integ.0624_schema.orders_raw_bronze") 
  return df
